# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

raw_train = pd.read_csv("train.csv")
raw_test = pd.read_csv("test.csv")

raw_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
print('Pclass')
print('Range: ' + str(raw_test['Pclass'].min()) + '-' + str(raw_test['Pclass'].max()))
print('Missing Values: ' + str(raw_test['Pclass'].size - raw_test['Pclass'].count()))
print()
print('Name')
print('Missing Values: ' + str(raw_test['Embarked'].size - raw_test['Embarked'].count()))
print()
print('Sex')
print('Missing Values: ' + str(raw_test['Sex'].size - raw_test['Sex'].count()))
print()
print('Age')
print('Range: ' + str(raw_test['Age'].min()) + '-' + str(raw_test['Age'].max()))
print('Missing Values: ' + str(raw_test['Age'].size - raw_test['Age'].count()))
print()
print('SibSp')
print('Range: ' + str(raw_test['SibSp'].min()) + '-' + str(raw_test['SibSp'].max()))
print('Missing Values: ' + str(raw_test['SibSp'].size - raw_test['SibSp'].count()))
print()
print('Parch')
print('Range: ' + str(raw_test['Parch'].min()) + '-' + str(raw_test['Parch'].max()))
print('Missing Values: ' + str(raw_test['Parch'].size - raw_test['Parch'].count()))
print()
print('Fare')
print('Range: ' + str(raw_test['Fare'].min()) + '-' + str(raw_test['Fare'].max()))
print('Missing Values: ' + str(raw_test['Fare'].size - raw_test['Fare'].count()))
print()
print('Embarked')
print('Missing Values: ' + str(raw_test['Embarked'].size - raw_test['Embarked'].count()))
# Out:
# Pclass
# Range: 1-3
# Missing Values: 0
#
# Name
# Missing Values: 0
#
# Sex
# Missing Values: 0
#
# Age
# Range: 0.17-76.0
# Missing Values: 86
#
# SibSp
# Range: 0-8
# Missing Values: 0
#
# Parch
# Range: 0-9
# Missing Values: 0
#
# Fare
# Range: 0.0-512.3292
# Missing Values: 1
#
# Embarked
# Missing Values: 0

# %%
age = raw_train['Age'].floordiv(10)
age.index = age
print(age.mean())
age.groupby(level=0).count()
# Out:
# 2.5252100840336134
# Age
# 0.0     62
# 1.0    102
# 2.0    220
# 3.0    167
# 4.0     89
# 5.0     48
# 6.0     19
# 7.0      6
# 8.0      1
# Name: Age, dtype: int64

# %%
fare = raw_train['Fare'].floordiv(50)
fare.index = fare
print(fare.mean())
fare.groupby(level=0).count()
# Out:
# 0.3221099887766554
# Fare
# 0.0     730
# 1.0     108
# 2.0      24
# 3.0       9
# 4.0      11
# 5.0       6
# 10.0      3
# Name: Fare, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
def transform(data,age_bin = 10,fare_bin = 50):
  titles = ["Mr", "Miss", "Mrs", "Master"]
  title = data['Name'].str.extract(r"([A-Za-z]+)\.", expand=False)
  title.replace(["Ms", "Mlle", "Mme"], "Miss", inplace=True)
  title.replace(["Lady"], "Mrs", inplace=True)
  title.replace(["Sir", "Rev"], "Mr", inplace=True)
  title[~title.isin(titles)] = "Others"
  title = title.map({'Mr':0,'Miss':1,'Mrs':2,'Master':3,'Others':4})
  sex = data['Sex'].map({'male':0,'female':1,np.nan:1})
  age = data['Age'].floordiv(age_bin,fill_value=data['Age'].mean())
  family = data['SibSp'] + data['Parch']
  alone = family == 0
  alone = alone.map({False:0,True:1})
  fare = data['Fare'].floordiv(fare_bin,fill_value=0)
  embarked = data['Embarked'].map({'S':0,'C':1,'Q':2})
  cleaned = pd.DataFrame({'Pclass':data['Pclass'],'Title':title,'Sex':sex,'Age':age,'Alone':alone,'Fare':fare,'Embarked':embarked})
  return cleaned

transform(raw_train)
# Out:
#      Pclass  Title  Sex  Age  Alone  Fare  Embarked
# 0         3      0    0  2.0      0   0.0       0.0
# 1         1      2    1  3.0      0   1.0       1.0
# 2         3      1    1  2.0      1   0.0       0.0
# 3         1      2    1  3.0      0   1.0       0.0
# 4         3      0    0  3.0      1   0.0       0.0
# ..      ...    ...  ...  ...    ...   ...       ...
# 886       2      0    0  2.0      1   0.0       0.0
# 887       1      1    1  1.0      1   0.0       0.0
# 888       3      1    1  2.0      0   0.0       0.0
# 889       1      0    0  2.0      1   0.0       1.0
# 890       3      0    0  3.0      1   0.0       2.0
#
# [891 rows x 7 columns]

# %% [markdown]
# # Training

# %%
def entropy(data):
  p1 = data['Survived'].mean();
  p0 = 1 - p1
  if p0 == 0 or p1 == 0: return 0
  return -1 * (p0*np.log2(p0) + p1*np.log2(p1))

entropy(raw_train)
# Out:
# np.float64(0.9607079018756469)

# %%
def train(data,labels,max_depth,min_improv=0,random=False):
  if(max_depth > 0):
    H = entropy(data)
    if(H > 0):
      if not random:
        min = 2
        for l in labels:
          groupby = data.groupby(by=l)
          e = 0
          for value, group in groupby:
            e += entropy(group) * len(group)/len(data)
          if e < min:
            min = e
            label = l
            g = groupby
        if min < H - min_improv:
          labels.remove(label)
          next = dict();
          for value, group in g:
            next.update({value:train(group,labels,max_depth-1)})
          return {'label':label,'entropy':H,'next':next}
      else:
        i = np.random.randint(len(labels))
        l = labels[i]
        groupby = data.groupby(by=l)
        labels.remove(l)
        next = dict();
        for value, group in groupby:
          next.update({value:train(group,labels,max_depth-1)})
        return {'label':l,'entropy':H,'next':next}
  return {'label':'End','entropy':entropy(data),'class': 0 if data['Survived'].mean() < .5 else 1}

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
model = train(data,labels,len(labels))
model
# Out:
# {'label': 'Title',
#  'entropy': np.float64(0.9607079018756469),
#  'next': {0: {'label': 'Pclass',
#    'entropy': np.float64(0.6258424755265808),
#    'next': {1: {'label': 'Age',
#      'entropy': np.float64(0.9357110512652843),
#      'next': {1.0: {'label': 'Fare',
#        'entropy': np.float64(0.8112781244591328),
#        'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#         2.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#         5.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#       2.0: {'label': 'Alone',
#        'entropy': np.float64(0.9494520153879484),
#        'next': {0: {'label': 'Embarked',
#          'entropy': np.float64(0.9910760598382222),
#          'next': {0.0: {'label': 'End',
#            'entropy': np.float64(0.9182958340544896),
#            'class': 0},
#           1.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1}}},
#         1: {'label': 'End',
#          'entropy': np.float64(0.9293636260137187),
#          'class': 0}}},
#       3.0: {'label': 'Sex',
#        'entropy': np.float64(0.998363672593813),
#        'next': {0: {'label': 'End',
#          'entropy': np.float64(0.998363672593813),
#          'class': 1}}},
#       4.0: {'label': 'End',
#        'entropy': np.float64(0.9852281360342515),
#        'class': 0},
#       5.0: {'label': 'End',
#        'entropy': np.float64(0.41381685030363374),
#        'class': 0},
#       6.0: {'label': 'End',
#        'entropy': np.float64(0.5032583347756457),
#        'class': 0},
#       7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#       8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#     2: {'label': 'End',
#      'entropy': np.float64(0.41083783851692773),
#      'class': 0},
#     3: {'label': 'End',
#      'entropy': np.float64(0.5084609436289887),
#      'class': 0}}},
#   1: {'label': 'End', 'entropy': np.float64(0.8759695775313525), 'class': 1},
#   2: {'label': 'End', 'entropy': np.float64(0.7344461802527669), 'class': 1},
#   3: {'label': 'End', 'entropy': np.float64(0.9837082626231857), 'class': 1},
#   4: {'label': 'End', 'entropy': np.float64(0.9709505944546686), 'class': 0}}}

# %%
def trainForest(data,max_depth, n_trees, frac=.5, random=True):
  models = []
  for i in range(n_trees):
    d = data.sample(frac=frac,replace=True)
    labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
    models += [train(d,labels,max_depth,random=random)]
  return models

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
models = trainForest(data,len(labels),10)
models
# Out:
# [{'label': 'Embarked',
#   'entropy': np.float64(0.9766650017367726),
#   'next': {0.0: {'label': 'Title',
#     'entropy': np.float64(0.9461282363800092),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.7029786560827124),
#       'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        2.0: {'label': 'Pclass',
#         'entropy': np.float64(0.6321302781219706),
#         'next': {1: {'label': 'Fare',
#           'entropy': np.float64(0.8904916402194913),
#           'next': {0.0: {'label': 'End',
#             'entropy': np.float64(0.9910760598382222),
#             'class': 0},
#            1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            4.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          2: {'label': 'End', 'entropy': 0, 'class': 0},
#          3: {'label': 'Alone',
#           'entropy': np.float64(0.6912898694057888),
#           'next': {0: {'label': 'End', 'entropy': 0, 'class': 0},
#            1: {'label': 'End',
#             'entropy': np.float64(0.7553754125614287),
#             'class': 0}}}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.9121156307204276),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.7642045065086203),
#         'class': 0},
#        5.0: {'label': 'End',
#         'entropy': np.float64(0.5032583347756457),
#         'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.9751190649408661),
#       'class': 1},
#      2: {'label': 'End', 'entropy': np.float64(0.74959525725948), 'class': 1},
#      3: {'label': 'End',
#       'entropy': np.float64(0.9182958340544896),
#       'class': 1},
#      4: {'label': 'End', 'entropy': 0, 'class': 0}}},
#    1.0: {'label': 'Sex',
#     'entropy': np.float64(0.9751190649408661),
#     'next': {0: {'label': 'End',
#       'entropy': np.float64(0.8390040613676977),
#       'class': 0},
#      1: {'label': 'End',
#       'entropy': np.float64(0.38431154412649693),
#       'class': 1}}},
#    2.0: {'label': 'End',
#     'entropy': np.float64(0.9731560354421095),
#     'class': 0}}},
#  {'label': 'Embarked',
#   'entropy': np.float64(0.9742587089641187),
#   'next': {0.0: {'label': 'Title',
#     'entropy': np.float64(0.9500796252338518),
#     'next': {0: {'label': 'Pclass',
#       'entropy': np.float64(0.6908938714350409),
#       'next': {1: {'label': 'Age',
#         'entropy': np.float64(0.9993375041688847),
#         'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          2.0: {'label': 'End',
#           'entropy': np.float64(0.6500224216483541),
#           'class': 1},
#          3.0: {'label': 'Fare',
#           'entropy': np.float64(0.9910760598382222),
#           'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 1},
#            1.0: {'label': 'Alone',
#             'entropy': np.float64(0.9852281360342515),
#             'next': {0: {'label': 'End',
#               'entropy': np.float64(1.0),
#               'class': 1},
#              1: {'label': 'End', 'entropy': 0, 'class': 0}}},
#            2.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#          4.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#          5.0: {'label': 'End',
#           'entropy': np.float64(0.6500224216483541),
#           'class': 0},
#          6.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2: {'label': 'End',
#         'entropy': np.float64(0.5665095065529053),
#         'class': 0},
#        3: {'label': 'End',
#         'entropy': np.float64(0.5377838418329641),
#         'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.9633355456726841),
#       'class': 1},
#      2: {'label': 'End',
#       'entropy': np.float64(0.7849920887641584),
#       'class': 1},
#      3: {'label': 'End',
#       'entropy': np.float64(0.8812908992306927),
#       'class': 1},
#      4: {'label': 'Sex',
#       'entropy': np.float64(0.9182958340544896),
#       'next': {0: {'label': 'End',
#         'entropy': np.float64(0.8112781244591328),
#         'class': 0},
#        1: {'label': 'End', 'entropy': 0, 'class': 1}}}}},
#    1.0: {'label': 'End',
#     'entropy': np.float64(0.9998900524545518),
#     'class': 1},
#    2.0: {'label': 'End',
#     'entropy': np.float64(0.999525689293649),
#     'class': 0}}},
#  {'label': 'Fare',
#   'entropy': np.float64(0.9730104712596368),
#   'next': {0.0: {'label': 'Title',
#     'entropy': np.float64(0.916411780708005),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.6275814813516917),
#       'next': {1.0: {'label': 'Pclass',
#         'entropy': np.float64(0.24988229283318544),
#         'next': {2: {'label': 'End',
#           'entropy': np.float64(0.7219280948873623),
#           'class': 0},
#          3: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2.0: {'label': 'Embarked',
#         'entropy': np.float64(0.6840384356390418),
#         'next': {0.0: {'label': 'Alone',
#           'entropy': np.float64(0.6601070987550469),
#           'next': {0: {'label': 'End', 'entropy': 0, 'class': 0},
#            1: {'label': 'End',
#             'entropy': np.float64(0.7219280948873623),
#             'class': 0}}},
#          1.0: {'label': 'End',
#           'entropy': np.float64(0.7732266742876346),
#           'class': 0},
#          2.0: {'label': 'End',
#           'entropy': np.float64(0.6500224216483541),
#           'class': 0}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.676941869780886),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.7642045065086203),
#         'class': 0},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        6.0: {'label': 'End',
#         'entropy': np.float64(0.5916727785823273),
#         'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.8865408928220899),
#       'class': 1},
#      2: {'label': 'End',
#       'entropy': np.float64(0.9899927915575186),
#       'class': 1},
#      3: {'label': 'End',
#       'entropy': np.float64(0.9494520153879484),
#       'class': 1},
#      4: {'label': 'Sex',
#       'entropy': np.float64(0.9709505944546686),
#       'next': {0: {'label': 'End',
#         'entropy': np.float64(0.9182958340544896),
#         'class': 0},
#        1: {'label': 'End', 'entropy': 0, 'class': 1}}}}},
#    1.0: {'label': 'End', 'entropy': np.float64(0.944387195013346), 'class': 1},
#    2.0: {'label': 'End',
#     'entropy': np.float64(0.7871265862012691),
#     'class': 1},
#    3.0: {'label': 'End', 'entropy': 0, 'class': 1},
#    4.0: {'label': 'End',
#     'entropy': np.float64(0.9182958340544896),
#     'class': 1},
#    5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#    10.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#  {'label': 'Alone',
#   'entropy': np.float64(0.9434990513635716),
#   'next': {0: {'label': 'Pclass',
#     'entropy': np.float64(0.9994243005775636),
#     'next': {1: {'label': 'Title',
#       'entropy': np.float64(0.7950402793845223),
#       'next': {0: {'label': 'Age',
#         'entropy': np.float64(0.9927744539878083),
#         'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          3.0: {'label': 'Fare',
#           'entropy': np.float64(0.9709505944546686),
#           'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            2.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#          4.0: {'label': 'Embarked',
#           'entropy': np.float64(0.8112781244591328),
#           'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 1},
#            1.0: {'label': 'End',
#             'entropy': np.float64(0.9182958340544896),
#             'class': 1}}},
#          5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          6.0: {'label': 'End',
#           'entropy': np.float64(0.8112781244591328),
#           'class': 1}}},
#        1: {'label': 'End',
#         'entropy': np.float64(0.3533593350214213),
#         'class': 1},
#        2: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      2: {'label': 'Sex',
#       'entropy': np.float64(0.8485481782946158),
#       'next': {0: {'label': 'End',
#         'entropy': np.float64(0.964078764808229),
#         'class': 0},
#        1: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      3: {'label': 'End',
#       'entropy': np.float64(0.7572182549240019),
#       'class': 0}}},
#    1: {'label': 'End', 'entropy': np.float64(0.853824841473004), 'class': 0}}},
#  {'label': 'Sex',
#   'entropy': np.float64(0.9338676527300767),
#   'next': {0: {'label': 'Fare',
#     'entropy': np.float64(0.6539167110696156),
#     'next': {0.0: {'label': 'Pclass',
#       'entropy': np.float64(0.5860284188204257),
#       'next': {1: {'label': 'Age',
#         'entropy': np.float64(0.907165767573082),
#         'next': {2.0: {'label': 'Embarked',
#           'entropy': np.float64(0.964078764808229),
#           'next': {0.0: {'label': 'Title',
#             'entropy': np.float64(0.9798687566511528),
#             'next': {0: {'label': 'Alone',
#               'entropy': np.float64(0.9798687566511528),
#               'next': {1: {'label': 'End',
#                 'entropy': np.float64(0.9798687566511528),
#                 'class': 0}}}}},
#            1.0: {'label': 'End',
#             'entropy': np.float64(0.9182958340544896),
#             'class': 0}}},
#          3.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#          4.0: {'label': 'End',
#           'entropy': np.float64(0.5916727785823273),
#           'class': 0},
#          5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          6.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2: {'label': 'End',
#         'entropy': np.float64(0.6722948170756379),
#         'class': 0},
#        3: {'label': 'End',
#         'entropy': np.float64(0.46724180329520937),
#         'class': 0}}},
#      1.0: {'label': 'End',
#       'entropy': np.float64(0.9760206482366149),
#       'class': 0},
#      2.0: {'label': 'End',
#       'entropy': np.float64(0.9182958340544896),
#       'class': 1},
#      4.0: {'label': 'End', 'entropy': 0, 'class': 0},
#      5.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#    1: {'label': 'End',
#     'entropy': np.float64(0.8668936705568642),
#     'class': 1}}},
#  {'label': 'Alone',
#   'entropy': np.float64(0.954019938387771),
#   'next': {0: {'label': 'Title',
#     'entropy': np.float64(0.9988714849476876),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.39993804743902756),
#       'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        2.0: {'label': 'Fare',
#         'entropy': np.float64(0.6962122601251458),
#         'next': {0.0: {'label': 'Embarked',
#           'entropy': np.float64(0.6840384356390418),
#           'next': {0.0: {'label': 'Pclass',
#             'entropy': np.float64(0.863120568566631),
#             'next': {2: {'label': 'End', 'entropy': 0, 'class': 0},
#              3: {'label': 'End',
#               'entropy': np.float64(0.9182958340544896),
#               'class': 0}}},
#            1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            2.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          1.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#          4.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        3.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.8112781244591328),
#         'class': 0},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.8997437586982626),
#       'class': 1},
#      2: {'label': 'End',
#       'entropy': np.float64(0.7871265862012691),
#       'class': 1},
#      3: {'label': 'Sex',
#       'entropy': np.float64(0.9798687566511528),
#       'next': {0: {'label': 'End',
#         'entropy': np.float64(0.9798687566511528),
#         'class': 1}}},
#      4: {'label': 'End', 'entropy': 0, 'class': 1}}},
#    1: {'label': 'End',
#     'entropy': np.float64(0.8871183908924201),
#     'class': 0}}},
#  {'label': 'Pclass',
#   'entropy': np.float64(0.9860148986230131),
#   'next': {1: {'label': 'Title',
#     'entropy': np.float64(0.9121156307204276),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.9182958340544896),
#       'next': {1.0: {'label': 'Fare',
#         'entropy': np.float64(1.0),
#         'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#        2.0: {'label': 'Embarked',
#         'entropy': np.float64(0.934068055375491),
#         'next': {0.0: {'label': 'Alone',
#           'entropy': np.float64(0.5665095065529053),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.8112781244591328),
#             'class': 0},
#            1: {'label': 'End',
#             'entropy': np.float64(0.4394969869215134),
#             'class': 0}}},
#          1.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.5916727785823275),
#         'class': 1},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.7219280948873623),
#         'class': 0},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.2667649878030259),
#       'class': 1},
#      2: {'label': 'End', 'entropy': 0, 'class': 1},
#      3: {'label': 'End', 'entropy': 0, 'class': 1},
#      4: {'label': 'End',
#       'entropy': np.float64(0.9182958340544896),
#       'class': 1}}},
#    2: {'label': 'Sex',
#     'entropy': np.float64(0.9994535015927485),
#     'next': {0: {'label': 'End',
#       'entropy': np.float64(0.7455178428108284),
#       'class': 0},
#      1: {'label': 'End',
#       'entropy': np.float64(0.15935006268563462),
#       'class': 1}}},
#    3: {'label': 'End',
#     'entropy': np.float64(0.8459170485484222),
#     'class': 0}}},
#  {'label': 'Embarked',
#   'entropy': np.float64(0.9358573442730366),
#   'next': {0.0: {'label': 'Title',
#     'entropy': np.float64(0.8746786950139878),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.5621019859911414),
#       'next': {1.0: {'label': 'Alone',
#         'entropy': np.float64(0.34511731494495285),
#         'next': {0: {'label': 'End', 'entropy': 0, 'class': 0},
#          1: {'label': 'Pclass',
#           'entropy': np.float64(0.4262286569981447),
#           'next': {2: {'label': 'End', 'entropy': 0, 'class': 0},
#            3: {'label': 'End',
#             'entropy': np.float64(0.4689955935892812),
#             'class': 0}}}}},
#        2.0: {'label': 'Fare',
#         'entropy': np.float64(0.5399357331112666),
#         'next': {0.0: {'label': 'End',
#           'entropy': np.float64(0.44295867853848536),
#           'class': 0},
#          1.0: {'label': 'End',
#           'entropy': np.float64(0.9709505944546686),
#           'class': 0}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.5349436990971066),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.8554508105601306),
#         'class': 0},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.9944423248022587),
#       'class': 1},
#      2: {'label': 'End',
#       'entropy': np.float64(0.9262122127346664),
#       'class': 1},
#      3: {'label': 'End',
#       'entropy': np.float64(0.9456603046006401),
#       'class': 1},
#      4: {'label': 'Sex',
#       'entropy': np.float64(0.9709505944546686),
#       'next': {0: {'label': 'End',
#         'entropy': np.float64(0.8112781244591328),
#         'class': 0},
#        1: {'label': 'End', 'entropy': 0, 'class': 1}}}}},
#    1.0: {'label': 'End',
#     'entropy': np.float64(0.9995708393473224),
#     'class': 1},
#    2.0: {'label': 'End',
#     'entropy': np.float64(0.9967916319816366),
#     'class': 0}}},
#  {'label': 'Alone',
#   'entropy': np.float64(0.9730104712596368),
#   'next': {0: {'label': 'Title',
#     'entropy': np.float64(0.9946937953613058),
#     'next': {0: {'label': 'Fare',
#       'entropy': np.float64(0.6631968402398287),
#       'next': {0.0: {'label': 'Embarked',
#         'entropy': np.float64(0.29181825659888583),
#         'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          1.0: {'label': 'Pclass',
#           'entropy': np.float64(0.5435644431995964),
#           'next': {1: {'label': 'End', 'entropy': 0, 'class': 0},
#            2: {'label': 'End', 'entropy': 0, 'class': 0},
#            3: {'label': 'End',
#             'entropy': np.float64(0.7219280948873623),
#             'class': 0}}},
#          2.0: {'label': 'End',
#           'entropy': np.float64(0.9182958340544896),
#           'class': 0}}},
#        1.0: {'label': 'Age',
#         'entropy': np.float64(0.9967916319816366),
#         'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          2.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#          3.0: {'label': 'End',
#           'entropy': np.float64(0.8112781244591328),
#           'class': 1},
#          4.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#          5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          6.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#        2.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        4.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.8865408928220899),
#       'class': 1},
#      2: {'label': 'End',
#       'entropy': np.float64(0.7444131797881749),
#       'class': 1},
#      3: {'label': 'Sex',
#       'entropy': np.float64(0.964078764808229),
#       'next': {0: {'label': 'End',
#         'entropy': np.float64(0.964078764808229),
#         'class': 1}}},
#      4: {'label': 'End', 'entropy': 0, 'class': 1}}},
#    1: {'label': 'End',
#     'entropy': np.float64(0.8973454677826594),
#     'class': 0}}},
#  {'label': 'Alone',
#   'entropy': np.float64(0.9766650017367726),
#   'next': {0: {'label': 'Title',
#     'entropy': np.float64(0.9999109429180594),
#     'next': {0: {'label': 'Embarked',
#       'entropy': np.float64(0.5691903437356829),
#       'next': {0.0: {'label': 'Fare',
#         'entropy': np.float64(0.32744491915447627),
#         'next': {0.0: {'label': 'Age',
#           'entropy': np.float64(0.20062232431271465),
#           'next': {1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            2.0: {'label': 'Pclass',
#             'entropy': np.float64(0.41381685030363374),
#             'next': {2: {'label': 'End', 'entropy': 0, 'class': 0},
#              3: {'label': 'End',
#               'entropy': np.float64(0.4394969869215134),
#               'class': 0}}},
#            3.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            4.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            5.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          1.0: {'label': 'End',
#           'entropy': np.float64(0.37123232664087563),
#           'class': 0},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 1},
#          3.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          5.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        1.0: {'label': 'End',
#         'entropy': np.float64(0.9852281360342515),
#         'class': 0},
#        2.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.9182958340544896),
#       'class': 1},
#      2: {'label': 'End',
#       'entropy': np.float64(0.7045767128725937),
#       'class': 1},
#      3: {'label': 'End',
#       'entropy': np.float64(0.9751190649408661),
#       'class': 1}}},
#    1: {'label': 'Sex',
#     'entropy': np.float64(0.9370535262287881),
#     'next': {0: {'label': 'End',
#       'entropy': np.float64(0.652044587772856),
#       'class': 0},
#      1: {'label': 'End',
#       'entropy': np.float64(0.6652735227649414),
#       'class': 1}}}}}]

# %% [markdown]
# # Testing

# %%
def testForest(data,models):
  correct = 0
  for i in data.index:
    vote = 0
    for model in models:
      layer = model
      while not layer['label'] == 'End':
        value = data[layer['label']][i]
        if value in layer['next']:
          layer = layer['next'][value]
        else:
          keys = list(layer['next'].keys())
          before = keys[0]
          for k in keys:
            after = k
            if(after > value): break
            before = k
          if after - value < value - before:
            layer = layer['next'][after]
          else:
            layer = layer['next'][before]
      vote += layer['class']
    vote = (0 if vote < 5 else 1)
    if vote == data['Survived'][i]: correct += 1
  return correct / len(data)

# %%
testForest(data,models)
# Out:
# 0.8013468013468014

# %% [markdown]
# # Evaluation

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,11):
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,len(labels),10,i*.1)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.8033707865168539
# 2: 0.797752808988764
# 3: 0.8033707865168539
# 4: 0.7696629213483146
# 5: 0.8033707865168539
# 6: 0.7808988764044944
# 7: 0.7921348314606742
# 8: 0.7471910112359551
# 9: 0.7865168539325843
# 10: 0.7865168539325843

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,30):
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,len(labels),i,)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.5842696629213483
# 2: 0.5842696629213483
# 3: 0.5842696629213483
# 4: 0.5842696629213483
# 5: 0.6179775280898876
# 6: 0.6966292134831461
# 7: 0.797752808988764
# 8: 0.8089887640449438
# 9: 0.8033707865168539
# 10: 0.8033707865168539
# 11: 0.797752808988764
# 12: 0.8089887640449438
# 13: 0.7865168539325843
# 14: 0.8089887640449438
# 15: 0.8089887640449438
# 16: 0.7640449438202247
# 17: 0.7752808988764045
# 18: 0.7640449438202247
# 19: 0.7640449438202247
# 20: 0.7808988764044944
# 21: 0.7752808988764045
# 22: 0.7696629213483146
# 23: 0.7584269662921348
# 24: 0.7696629213483146
# 25: 0.7584269662921348
# 26: 0.7696629213483146
# 27: 0.7584269662921348
# 28: 0.7640449438202247
# 29: 0.7808988764044944

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,11):
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,len(labels),10,i*.1,random=False)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.7921348314606742
# 2: 0.7865168539325843
# 3: 0.7921348314606742
# 4: 0.7921348314606742
# 5: 0.7808988764044944
# 6: 0.8033707865168539
# 7: 0.7865168539325843
# 8: 0.7921348314606742
# 9: 0.8033707865168539
# 10: 0.7921348314606742

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,30):
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,len(labels),i,.8,random=False)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.6235955056179775
# 2: 0.6235955056179775
# 3: 0.6235955056179775
# 4: 0.6235955056179775
# 5: 0.8146067415730337
# 6: 0.8146067415730337
# 7: 0.8033707865168539
# 8: 0.8202247191011236
# 9: 0.797752808988764
# 10: 0.7865168539325843
# 11: 0.7808988764044944
# 12: 0.7865168539325843
# 13: 0.7921348314606742
# 14: 0.8089887640449438
# 15: 0.7808988764044944
# 16: 0.7808988764044944
# 17: 0.7865168539325843
# 18: 0.7808988764044944
# 19: 0.7808988764044944
# 20: 0.7808988764044944
# 21: 0.7808988764044944
# 22: 0.7808988764044944
# 23: 0.7921348314606742
# 24: 0.7696629213483146
# 25: 0.7808988764044944
# 26: 0.7808988764044944
# 27: 0.7808988764044944
# 28: 0.7808988764044944
# 29: 0.7808988764044944

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
for i in range(len(labels)):
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,i+1,10,.8,random=False)
  print(str(i+1) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.8370786516853933
# 2: 0.8370786516853933
# 3: 0.8370786516853933
# 4: 0.8202247191011236
# 5: 0.8146067415730337
# 6: 0.8202247191011236
# 7: 0.8146067415730337

# %%
for a in range(1,100,1):
  data = transform(raw_train,age_bin=a)
  data['Survived'] = raw_train['Survived']
  training = data.sample(frac=.8)
  validation = data.drop(training.index)
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,len(labels),10,.8,random=False)
  print(str(a) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.7584269662921348
# 2: 0.7640449438202247
# 3: 0.7865168539325843
# 4: 0.7471910112359551
# 5: 0.7865168539325843
# 6: 0.7584269662921348
# 7: 0.7808988764044944
# 8: 0.7808988764044944
# 9: 0.7584269662921348
# 10: 0.8146067415730337
# 11: 0.797752808988764
# 12: 0.7247191011235955
# 13: 0.797752808988764
# 14: 0.7696629213483146
# 15: 0.8202247191011236
# 16: 0.7584269662921348
# 17: 0.797752808988764
# 18: 0.7865168539325843
# 19: 0.8370786516853933
# 20: 0.8258426966292135
# 21: 0.797752808988764
# 22: 0.7752808988764045
# 23: 0.7696629213483146
# 24: 0.7303370786516854
# 25: 0.7528089887640449
# 26: 0.7247191011235955
# 27: 0.8370786516853933
# 28: 0.8146067415730337
# 29: 0.8089887640449438
# 30: 0.7247191011235955
# 31: 0.8089887640449438
# 32: 0.7303370786516854
# 33: 0.8146067415730337
# 34: 0.8651685393258427
# 35: 0.8258426966292135
# 36: 0.7247191011235955
# 37: 0.8089887640449438
# 38: 0.7303370786516854
# 39: 0.7471910112359551
# 40: 0.8202247191011236
# 41: 0.7415730337078652
# 42: 0.7696629213483146
# 43: 0.7921348314606742
# 44: 0.7415730337078652
# 45: 0.7865168539325843
# 46: 0.7640449438202247
# 47: 0.7696629213483146
# 48: 0.7752808988764045
# 49: 0.7584269662921348
# 50: 0.7191011235955056
# 51: 0.8202247191011236
# 52: 0.7584269662921348
# 53: 0.8146067415730337
# 54: 0.7584269662921348
# 55: 0.7528089887640449
# 56: 0.7247191011235955
# 57: 0.7752808988764045
# 58: 0.7921348314606742
# 59: 0.797752808988764
# 60: 0.8426966292134831
# 61: 0.8089887640449438
# 62: 0.8033707865168539
# 63: 0.7808988764044944
# 64: 0.7752808988764045
# 65: 0.8314606741573034
# 66: 0.7191011235955056
# 67: 0.7752808988764045
# 68: 0.7921348314606742
# 69: 0.7696629213483146
# 70: 0.797752808988764
# 71: 0.8033707865168539
# 72: 0.7808988764044944
# 73: 0.8202247191011236
# 74: 0.7134831460674157
# 75: 0.797752808988764
# 76: 0.7528089887640449
# 77: 0.7471910112359551
# 78: 0.7921348314606742
# 79: 0.7921348314606742
# 80: 0.7471910112359551
# 81: 0.7528089887640449
# 82: 0.8146067415730337
# 83: 0.8033707865168539
# 84: 0.7808988764044944
# 85: 0.848314606741573
# 86: 0.7865168539325843
# 87: 0.7528089887640449
# 88: 0.8258426966292135
# 89: 0.7584269662921348
# 90: 0.7584269662921348
# 91: 0.7528089887640449
# 92: 0.7471910112359551
# 93: 0.7696629213483146
# 94: 0.7921348314606742
# 95: 0.7640449438202247
# 96: 0.7584269662921348
# 97: 0.7865168539325843
# 98: 0.7471910112359551
# 99: 0.7528089887640449

# %%
for f in range(5,500,5):
  data = transform(raw_train,age_bin=10,fare_bin=f)
  data['Survived'] = raw_train['Survived']
  training = data.sample(frac=.8)
  validation = data.drop(training.index)
  labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
  models = trainForest(training,len(labels),10,.8,random=False)
  print(str(f) + ': ' + str(testForest(validation,models)))
# Out:
# 5: 0.7078651685393258
# 10: 0.8426966292134831
# 15: 0.7752808988764045
# 20: 0.7640449438202247
# 25: 0.8033707865168539
# 30: 0.7865168539325843
# 35: 0.7865168539325843
# 40: 0.8033707865168539
# 45: 0.7752808988764045
# 50: 0.7752808988764045
# 55: 0.7752808988764045
# 60: 0.797752808988764
# 65: 0.7640449438202247
# 70: 0.8033707865168539
# 75: 0.8089887640449438
# 80: 0.7865168539325843
# 85: 0.7808988764044944
# 90: 0.7359550561797753
# 95: 0.7528089887640449
# 100: 0.7752808988764045
# 105: 0.7865168539325843
# 110: 0.7528089887640449
# 115: 0.7528089887640449
# 120: 0.7696629213483146
# 125: 0.7415730337078652
# 130: 0.7752808988764045
# 135: 0.7865168539325843
# 140: 0.7528089887640449
# 145: 0.7808988764044944
# 150: 0.8146067415730337
# 155: 0.7865168539325843
# 160: 0.7921348314606742
# 165: 0.7808988764044944
# 170: 0.7640449438202247
# 175: 0.8426966292134831
# 180: 0.7865168539325843
# 185: 0.7921348314606742
# 190: 0.7415730337078652
# 195: 0.7921348314606742
# 200: 0.7528089887640449
# 205: 0.8426966292134831
# 210: 0.797752808988764
# 215: 0.7752808988764045
# 220: 0.7471910112359551
# 225: 0.7752808988764045
# 230: 0.7865168539325843
# 235: 0.8089887640449438
# 240: 0.7471910112359551
# 245: 0.7752808988764045
# 250: 0.797752808988764
# 255: 0.7640449438202247
# 260: 0.8426966292134831
# 265: 0.7921348314606742
# 270: 0.7640449438202247
# 275: 0.8202247191011236
# 280: 0.7640449438202247
# 285: 0.8033707865168539
# 290: 0.8258426966292135
# 295: 0.7359550561797753
# 300: 0.7696629213483146
# 305: 0.7584269662921348
# 310: 0.7584269662921348
# 315: 0.7584269662921348
# 320: 0.8146067415730337
# 325: 0.7640449438202247
# 330: 0.8033707865168539
# 335: 0.7584269662921348
# 340: 0.7921348314606742
# 345: 0.7696629213483146
# 350: 0.7808988764044944
# 355: 0.7584269662921348
# 360: 0.7752808988764045
# 365: 0.7584269662921348
# 370: 0.7921348314606742
# 375: 0.8089887640449438
# 380: 0.7696629213483146
# 385: 0.7865168539325843
# 390: 0.8033707865168539
# 395: 0.7584269662921348
# 400: 0.7921348314606742
# 405: 0.7640449438202247
# 410: 0.7808988764044944
# 415: 0.7921348314606742
# 420: 0.7808988764044944
# 425: 0.7359550561797753
# 430: 0.7808988764044944
# 435: 0.7191011235955056
# 440: 0.7865168539325843
# 445: 0.7584269662921348
# 450: 0.8033707865168539
# 455: 0.7584269662921348
# 460: 0.8033707865168539
# 465: 0.7696629213483146
# 470: 0.7865168539325843
# 475: 0.7752808988764045
# 480: 0.7808988764044944
# 485: 0.8146067415730337
# 490: 0.7191011235955056
# 495: 0.7865168539325843

# %% [markdown]
# # Prediction

# %%
def predictForest(data,models):
  out = pd.DataFrame(columns=['PassengerId','Survived'])
  out['PassengerId'] = data['PassengerId']
  for i in data.index:
    vote = 0
    for model in models:
      layer = model
      while not layer['label'] == 'End':
        value = data[layer['label']][i]
        if value in layer['next']:
          layer = layer['next'][value]
        else:
          keys = list(layer['next'].keys())
          before = keys[0]
          for k in keys:
            after = k
            if(after > value): break
            before = k
          if after - value < value - before:
            layer = layer['next'][after]
          else:
            layer = layer['next'][before]
      vote += layer['class']
    vote = 0 if vote < 5 else 1
    out.loc[i,'Survived'] = vote
  return out

# %%
data = transform(raw_train,age_bin=10,fare_bin=100)
data['Survived'] = raw_train['Survived']
labels = ['Pclass','Title','Sex','Age','Alone','Fare','Embarked']
models = trainForest(data,len(labels),10,.8,random=False)

# %%
data = transform(raw_test,age_bin=5,fare_bin=20)
data['PassengerId'] = raw_test['PassengerId']
out = predictForest(data,models)
out.to_csv('RandomForest.csv', index = False)
out
# Out:
#      PassengerId Survived
# 0            892        0
# 1            893        1
# 2            894        0
# 3            895        0
# 4            896        1
# ..           ...      ...
# 413         1305        0
# 414         1306        1
# 415         1307        0
# 416         1308        0
# 417         1309        1
#
# [418 rows x 2 columns]
