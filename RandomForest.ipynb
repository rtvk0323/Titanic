# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

raw_train = pd.read_csv("train.csv")
raw_test = pd.read_csv("test.csv")

raw_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
print('Pclass')
print('Range: ' + str(raw_test['Pclass'].min()) + '-' + str(raw_test['Pclass'].max()))
print('Missing Values: ' + str(raw_test['Pclass'].size - raw_test['Pclass'].count()))
print()
print('Sex')
print('Missing Values: ' + str(raw_test['Sex'].size - raw_test['Sex'].count()))
print()
print('Age')
print('Range: ' + str(raw_test['Age'].min()) + '-' + str(raw_test['Age'].max()))
print('Missing Values: ' + str(raw_test['Age'].size - raw_test['Age'].count()))
print()
print('SibSp')
print('Range: ' + str(raw_test['SibSp'].min()) + '-' + str(raw_test['SibSp'].max()))
print('Missing Values: ' + str(raw_test['SibSp'].size - raw_test['SibSp'].count()))
print()
print('Parch')
print('Range: ' + str(raw_test['Parch'].min()) + '-' + str(raw_test['Parch'].max()))
print('Missing Values: ' + str(raw_test['Parch'].size - raw_test['Parch'].count()))
print()
print('Fare')
print('Range: ' + str(raw_test['Fare'].min()) + '-' + str(raw_test['Fare'].max()))
print('Missing Values: ' + str(raw_test['Fare'].size - raw_test['Fare'].count()))
print()
print('Embarked')
print('Missing Values: ' + str(raw_test['Embarked'].size - raw_test['Embarked'].count()))
# Out:
# Pclass
# Range: 1-3
# Missing Values: 0
#
# Sex
# Missing Values: 0
#
# Age
# Range: 0.17-76.0
# Missing Values: 86
#
# SibSp
# Range: 0-8
# Missing Values: 0
#
# Parch
# Range: 0-9
# Missing Values: 0
#
# Fare
# Range: 0.0-512.3292
# Missing Values: 1
#
# Embarked
# Missing Values: 0

# %%
age = raw_train['Age'].floordiv(10)
age.index = age
print(age.mean())
age.groupby(level=0).count()
# Out:
# 2.5252100840336134
# Age
# 0.0     62
# 1.0    102
# 2.0    220
# 3.0    167
# 4.0     89
# 5.0     48
# 6.0     19
# 7.0      6
# 8.0      1
# Name: Age, dtype: int64

# %%
fare = raw_train['Fare'].floordiv(50)
fare.index = fare
print(fare.mean())
fare.groupby(level=0).count()
# Out:
# 0.3221099887766554
# Fare
# 0.0     730
# 1.0     108
# 2.0      24
# 3.0       9
# 4.0      11
# 5.0       6
# 10.0      3
# Name: Fare, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
def transform(data,age_bin = 10,fare_bin = 50):
  titles = ["Mr", "Miss", "Mrs", "Master"]
  title = data['Name'].str.extract(r"([A-Za-z]+)\.", expand=False)
  title.replace(["Ms", "Mlle", "Mme"], "Miss", inplace=True)
  title.replace(["Lady"], "Mrs", inplace=True)
  title.replace(["Sir", "Rev"], "Mr", inplace=True)
  title[~title.isin(titles)] = "Others"
  sex = data['Sex'].map({'male':0,'female':1,np.nan:1})
  age = data['Age'].floordiv(age_bin,fill_value=data['Age'].mean())
  fare = data['Fare'].floordiv(fare_bin,fill_value=0)
  embarked = data['Embarked'].map({'S':0,'C':1,'Q':2})
  cleaned = pd.DataFrame({'Pclass':data['Pclass'],'Title':title,'Sex':sex,'Age':age,'SibSp':data['SibSp'],'Parch':data['Parch'],'Fare':fare,'Embarked':embarked})
  return cleaned

transform(raw_train)
# Out:
#      Pclass Title  Sex  Age  SibSp  Parch  Fare  Embarked
# 0         3    Mr    0  2.0      1      0   0.0       0.0
# 1         1   Mrs    1  3.0      1      0   1.0       1.0
# 2         3  Miss    1  2.0      0      0   0.0       0.0
# 3         1   Mrs    1  3.0      1      0   1.0       0.0
# 4         3    Mr    0  3.0      0      0   0.0       0.0
# ..      ...   ...  ...  ...    ...    ...   ...       ...
# 886       2    Mr    0  2.0      0      0   0.0       0.0
# 887       1  Miss    1  1.0      0      0   0.0       0.0
# 888       3  Miss    1  2.0      1      2   0.0       0.0
# 889       1    Mr    0  2.0      0      0   0.0       1.0
# 890       3    Mr    0  3.0      0      0   0.0       2.0
#
# [891 rows x 8 columns]

# %% [markdown]
# # Training

# %%
def entropy(data):
  p1 = data['Survived'].mean();
  p0 = 1 - p1
  if p0 == 0 or p1 == 0: return 0
  return -1 * (p0*np.log2(p0) + p1*np.log2(p1))

entropy(raw_train)
# Out:
# np.float64(0.9607079018756469)

# %%
def train(data,labels,max_depth,min_improv=0,random=False):
  if(max_depth > 0):
    H = entropy(data)
    if(H > 0):
      if not random:
        min = 2
        for l in labels:
          groupby = data.groupby(by=l)
          e = 0
          for value, group in groupby:
            e += entropy(group) * len(group)/len(data)
          if e < min:
            min = e
            label = l
            g = groupby
        if min < H - min_improv:
          labels.remove(label)
          next = dict();
          for value, group in g:
            next.update({value:train(group,labels,max_depth-1)})
          return {'label':label,'entropy':H,'next':next}
      else:
        i = np.random.randint(len(labels))
        l = labels[i]
        groupby = data.groupby(by=l)
        labels.remove(l)
        next = dict();
        for value, group in groupby:
          next.update({value:train(group,labels,max_depth-1)})
        return {'label':l,'entropy':H,'next':next}
  return {'label':'End','entropy':entropy(data),'class': 0 if data['Survived'].mean() < .5 else 1}

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
model = train(data,labels,len(labels))
model
# Out:
# {'label': 'Title',
#  'entropy': np.float64(0.9607079018756469),
#  'next': {'Master': {'label': 'SibSp',
#    'entropy': np.float64(0.9837082626231857),
#    'next': {0: {'label': 'End', 'entropy': 0, 'class': 1},
#     1: {'label': 'End', 'entropy': 0, 'class': 1},
#     2: {'label': 'End', 'entropy': 0, 'class': 1},
#     3: {'label': 'End', 'entropy': 0, 'class': 0},
#     4: {'label': 'Parch',
#      'entropy': np.float64(0.4689955935892812),
#      'next': {1: {'label': 'End', 'entropy': 0, 'class': 0},
#       2: {'label': 'End',
#        'entropy': np.float64(0.9182958340544896),
#        'class': 0}}},
#     5: {'label': 'End', 'entropy': 0, 'class': 0},
#     8: {'label': 'End', 'entropy': 0, 'class': 0}}},
#   'Miss': {'label': 'Pclass',
#    'entropy': np.float64(0.8759695775313525),
#    'next': {1: {'label': 'Age',
#      'entropy': np.float64(0.24602257822033174),
#      'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 0},
#       1.0: {'label': 'End', 'entropy': 0, 'class': 1},
#       2.0: {'label': 'End', 'entropy': 0, 'class': 1},
#       3.0: {'label': 'End', 'entropy': 0, 'class': 1},
#       4.0: {'label': 'End', 'entropy': 0, 'class': 1},
#       5.0: {'label': 'Fare',
#        'entropy': np.float64(0.8112781244591328),
#        'next': {0.0: {'label': 'Embarked',
#          'entropy': np.float64(1.0),
#          'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 1},
#           1.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#         1.0: {'label': 'End', 'entropy': 0, 'class': 1},
#         2.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#       6.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#     2: {'label': 'End',
#      'entropy': np.float64(0.31599713297842474),
#      'class': 1},
#     3: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1}}},
#   'Mr': {'label': 'End',
#    'entropy': np.float64(0.6258424755265808),
#    'class': 0},
#   'Mrs': {'label': 'End',
#    'entropy': np.float64(0.7344461802527669),
#    'class': 1},
#   'Others': {'label': 'Sex',
#    'entropy': np.float64(0.9709505944546686),
#    'next': {0: {'label': 'End',
#      'entropy': np.float64(0.8904916402194913),
#      'class': 0},
#     1: {'label': 'End', 'entropy': 0, 'class': 1}}}}}

# %%
def trainForest(data,max_depth, n_trees, frac=.5, random=True):
  models = []
  for i in range(n_trees):
    d = data.sample(frac=frac,replace=True)
    labels = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
    models += [train(d,labels,max_depth,random=random)]
  return models

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
models = trainForest(data,len(labels),10)
models
# Out:
# [{'label': 'Fare',
#   'entropy': np.float64(0.9929678708113485),
#   'next': {0.0: {'label': 'Sex',
#     'entropy': np.float64(0.9559644273086976),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.7445646141410556),
#       'next': {0.0: {'label': 'SibSp',
#         'entropy': np.float64(0.9402859586706311),
#         'next': {0: {'label': 'End', 'entropy': 0, 'class': 1},
#          1: {'label': 'End', 'entropy': 0, 'class': 1},
#          2: {'label': 'End', 'entropy': 0, 'class': 1},
#          4: {'label': 'Parch',
#           'entropy': np.float64(0.9182958340544896),
#           'next': {1: {'label': 'End', 'entropy': 0, 'class': 0},
#            2: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1}}},
#          5: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        1.0: {'label': 'Pclass',
#         'entropy': np.float64(0.7219280948873623),
#         'next': {2: {'label': 'End', 'entropy': 0, 'class': 0},
#          3: {'label': 'Embarked',
#           'entropy': np.float64(0.7918583525674836),
#           'next': {0.0: {'label': 'End',
#             'entropy': np.float64(0.7918583525674836),
#             'class': 0}}}}},
#        2.0: {'label': 'End',
#         'entropy': np.float64(0.7070040649747601),
#         'class': 0},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.7382848661434506),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.7424875695421236),
#         'class': 0},
#        5.0: {'label': 'End',
#         'entropy': np.float64(0.37123232664087563),
#         'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.8582307926411411),
#       'class': 1}}},
#    1.0: {'label': 'End',
#     'entropy': np.float64(0.8301899714180441),
#     'class': 1},
#    2.0: {'label': 'End',
#     'entropy': np.float64(0.6962122601251458),
#     'class': 1},
#    3.0: {'label': 'End',
#     'entropy': np.float64(0.9182958340544896),
#     'class': 1},
#    4.0: {'label': 'End',
#     'entropy': np.float64(0.8112781244591328),
#     'class': 1},
#    5.0: {'label': 'End',
#     'entropy': np.float64(0.9182958340544896),
#     'class': 1},
#    10.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#  {'label': 'SibSp',
#   'entropy': np.float64(0.9648863100149885),
#   'next': {0: {'label': 'Sex',
#     'entropy': np.float64(0.9366673818775626),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.6370237433649951),
#       'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 1},
#        1.0: {'label': 'Pclass',
#         'entropy': np.float64(0.5032583347756457),
#         'next': {2: {'label': 'End', 'entropy': 0, 'class': 0},
#          3: {'label': 'End',
#           'entropy': np.float64(0.5665095065529053),
#           'class': 0}}},
#        2.0: {'label': 'Embarked',
#         'entropy': np.float64(0.44506485705083865),
#         'next': {0.0: {'label': 'Fare',
#           'entropy': np.float64(0.3255517134879514),
#           'next': {0.0: {'label': 'End',
#             'entropy': np.float64(0.2811937964320427),
#             'class': 0},
#            1.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1}}},
#          1.0: {'label': 'Parch',
#           'entropy': np.float64(0.7871265862012691),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.8112781244591328),
#             'class': 0},
#            1: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          2.0: {'label': 'End',
#           'entropy': np.float64(0.5916727785823273),
#           'class': 0}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.9262122127346664),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.6343095546405662),
#         'class': 0},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.7620849248057242),
#       'class': 1}}},
#    1: {'label': 'End', 'entropy': np.float64(0.9994730201859836), 'class': 1},
#    2: {'label': 'End', 'entropy': np.float64(0.9798687566511528), 'class': 1},
#    3: {'label': 'End', 'entropy': np.float64(0.863120568566631), 'class': 0},
#    4: {'label': 'End', 'entropy': 0, 'class': 0},
#    5: {'label': 'End', 'entropy': 0, 'class': 0},
#    8: {'label': 'End', 'entropy': 0, 'class': 0}}},
#  {'label': 'Sex',
#   'entropy': np.float64(0.9523443161799906),
#   'next': {0: {'label': 'Age',
#     'entropy': np.float64(0.6274303352684106),
#     'next': {0.0: {'label': 'SibSp',
#       'entropy': np.float64(0.9709505944546686),
#       'next': {0: {'label': 'End', 'entropy': 0, 'class': 1},
#        1: {'label': 'End', 'entropy': 0, 'class': 1},
#        4: {'label': 'End', 'entropy': 0, 'class': 0},
#        5: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1.0: {'label': 'Embarked',
#       'entropy': np.float64(0.24988229283318544),
#       'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        1.0: {'label': 'Parch',
#         'entropy': np.float64(0.8112781244591328),
#         'next': {0: {'label': 'End',
#           'entropy': np.float64(0.9182958340544896),
#           'class': 0},
#          1: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      2.0: {'label': 'Pclass',
#       'entropy': np.float64(0.6301628871027962),
#       'next': {1: {'label': 'Fare',
#         'entropy': np.float64(0.9774178175281716),
#         'next': {0.0: {'label': 'End',
#           'entropy': np.float64(0.9612366047228759),
#           'class': 0},
#          1.0: {'label': 'End',
#           'entropy': np.float64(0.9182958340544896),
#           'class': 1},
#          4.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2: {'label': 'End',
#         'entropy': np.float64(0.35335933502142136),
#         'class': 0},
#        3: {'label': 'End',
#         'entropy': np.float64(0.5597404598417696),
#         'class': 0}}},
#      3.0: {'label': 'End',
#       'entropy': np.float64(0.6572729784684465),
#       'class': 0},
#      4.0: {'label': 'End',
#       'entropy': np.float64(0.5787946246321198),
#       'class': 0},
#      5.0: {'label': 'End',
#       'entropy': np.float64(0.3227569588973982),
#       'class': 0},
#      6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#      7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#      8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#    1: {'label': 'End',
#     'entropy': np.float64(0.8342867421739535),
#     'class': 1}}},
#  {'label': 'Parch',
#   'entropy': np.float64(0.9789513902784714),
#   'next': {0: {'label': 'Sex',
#     'entropy': np.float64(0.9541618419343874),
#     'next': {0: {'label': 'Pclass',
#       'entropy': np.float64(0.6648831108951809),
#       'next': {1: {'label': 'Age',
#         'entropy': np.float64(0.9788698505067783),
#         'next': {2.0: {'label': 'Fare',
#           'entropy': np.float64(0.9967916319816366),
#           'next': {0.0: {'label': 'End',
#             'entropy': np.float64(0.9182958340544896),
#             'class': 1},
#            1.0: {'label': 'Embarked',
#             'entropy': np.float64(0.9182958340544896),
#             'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 0},
#              1.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#            2.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            4.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          3.0: {'label': 'SibSp',
#           'entropy': np.float64(0.9182958340544896),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.863120568566631),
#             'class': 0},
#            1: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1}}},
#          4.0: {'label': 'End',
#           'entropy': np.float64(0.9456603046006401),
#           'class': 0},
#          5.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#          6.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2: {'label': 'End',
#         'entropy': np.float64(0.49418293484978865),
#         'class': 0},
#        3: {'label': 'End',
#         'entropy': np.float64(0.5412664421908895),
#         'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.7106768538561228),
#       'class': 1}}},
#    1: {'label': 'End', 'entropy': np.float64(0.9863676072907088), 'class': 1},
#    2: {'label': 'End', 'entropy': np.float64(0.9733854352299556), 'class': 1},
#    4: {'label': 'End', 'entropy': 0, 'class': 0},
#    5: {'label': 'End', 'entropy': np.float64(0.6500224216483541), 'class': 0},
#    6: {'label': 'End', 'entropy': 0, 'class': 0}}},
#  {'label': 'Sex',
#   'entropy': np.float64(0.9255890222850668),
#   'next': {0: {'label': 'Age',
#     'entropy': np.float64(0.6055087774162944),
#     'next': {0.0: {'label': 'SibSp',
#       'entropy': np.float64(0.9940302114769565),
#       'next': {0: {'label': 'End', 'entropy': 0, 'class': 1},
#        1: {'label': 'End', 'entropy': 0, 'class': 1},
#        3: {'label': 'End', 'entropy': 0, 'class': 0},
#        4: {'label': 'End', 'entropy': 0, 'class': 0},
#        5: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1.0: {'label': 'Fare',
#       'entropy': np.float64(0.4798320236161285),
#       'next': {0.0: {'label': 'Parch',
#         'entropy': np.float64(0.4021791902022728),
#         'next': {0: {'label': 'Pclass',
#           'entropy': np.float64(0.4537163391869448),
#           'next': {2: {'label': 'End', 'entropy': 0, 'class': 0},
#            3: {'label': 'Embarked',
#             'entropy': np.float64(0.4854607607459134),
#             'next': {0.0: {'label': 'End',
#               'entropy': np.float64(0.5032583347756457),
#               'class': 0},
#              2.0: {'label': 'End', 'entropy': 0, 'class': 0}}}}},
#          1: {'label': 'End', 'entropy': 0, 'class': 0},
#          2: {'label': 'End', 'entropy': 0, 'class': 0},
#          3: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        1.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        2.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#        5.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      2.0: {'label': 'End',
#       'entropy': np.float64(0.5309895737517842),
#       'class': 0},
#      3.0: {'label': 'End',
#       'entropy': np.float64(0.4820661480830931),
#       'class': 0},
#      4.0: {'label': 'End',
#       'entropy': np.float64(0.6665783579949205),
#       'class': 0},
#      5.0: {'label': 'End',
#       'entropy': np.float64(0.4394969869215134),
#       'class': 0},
#      6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#      7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#      8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#    1: {'label': 'End',
#     'entropy': np.float64(0.8828524276472873),
#     'class': 1}}},
#  {'label': 'Fare',
#   'entropy': np.float64(0.9717321019586931),
#   'next': {0.0: {'label': 'Sex',
#     'entropy': np.float64(0.9192452721303128),
#     'next': {0: {'label': 'Pclass',
#       'entropy': np.float64(0.6612339922271747),
#       'next': {1: {'label': 'Age',
#         'entropy': np.float64(0.9876925088958033),
#         'next': {2.0: {'label': 'Embarked',
#           'entropy': np.float64(0.6500224216483541),
#           'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            1.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#          3.0: {'label': 'End',
#           'entropy': np.float64(0.7219280948873623),
#           'class': 1},
#          4.0: {'label': 'End',
#           'entropy': np.float64(0.9852281360342515),
#           'class': 1},
#          5.0: {'label': 'End',
#           'entropy': np.float64(0.9182958340544896),
#           'class': 0},
#          6.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        2: {'label': 'Parch',
#         'entropy': np.float64(0.54991090463341),
#         'next': {0: {'label': 'SibSp',
#           'entropy': np.float64(0.4689955935892812),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.5435644431995964),
#             'class': 0},
#            1: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          1: {'label': 'End',
#           'entropy': np.float64(0.9182958340544896),
#           'class': 1},
#          2: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        3: {'label': 'End',
#         'entropy': np.float64(0.6075038633139964),
#         'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.8992140950457247),
#       'class': 1}}},
#    1.0: {'label': 'End',
#     'entropy': np.float64(0.9081783472997051),
#     'class': 1},
#    2.0: {'label': 'End',
#     'entropy': np.float64(0.9182958340544896),
#     'class': 1},
#    3.0: {'label': 'End',
#     'entropy': np.float64(0.9709505944546686),
#     'class': 1},
#    4.0: {'label': 'End',
#     'entropy': np.float64(0.9182958340544896),
#     'class': 1},
#    5.0: {'label': 'End', 'entropy': 0, 'class': 0},
#    10.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#  {'label': 'SibSp',
#   'entropy': np.float64(0.9811182620059425),
#   'next': {0: {'label': 'Sex',
#     'entropy': np.float64(0.9717544755250673),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.7866261099706012),
#       'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 1},
#        1.0: {'label': 'Pclass',
#         'entropy': np.float64(0.8112781244591328),
#         'next': {1: {'label': 'End', 'entropy': 0, 'class': 1},
#          2: {'label': 'End',
#           'entropy': np.float64(0.6500224216483541),
#           'class': 0},
#          3: {'label': 'End',
#           'entropy': np.float64(0.7642045065086203),
#           'class': 0}}},
#        2.0: {'label': 'Fare',
#         'entropy': np.float64(0.6876445334580581),
#         'next': {0.0: {'label': 'Embarked',
#           'entropy': np.float64(0.6800770457282798),
#           'next': {0.0: {'label': 'Parch',
#             'entropy': np.float64(0.6242741010130388),
#             'next': {0: {'label': 'End',
#               'entropy': np.float64(0.6292492238560345),
#               'class': 0},
#              1: {'label': 'End', 'entropy': 0, 'class': 0}}},
#            1.0: {'label': 'End',
#             'entropy': np.float64(0.7424875695421236),
#             'class': 0},
#            2.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1}}},
#          1.0: {'label': 'End',
#           'entropy': np.float64(0.9709505944546686),
#           'class': 0},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          4.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.8418521897563207),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.8524051786494786),
#         'class': 0},
#        5.0: {'label': 'End',
#         'entropy': np.float64(0.9456603046006401),
#         'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.7686913027030167),
#       'class': 1}}},
#    1: {'label': 'End', 'entropy': np.float64(0.9999507304328823), 'class': 1},
#    2: {'label': 'End', 'entropy': np.float64(0.9182958340544896), 'class': 1},
#    3: {'label': 'End', 'entropy': np.float64(0.8112781244591328), 'class': 0},
#    4: {'label': 'End', 'entropy': np.float64(0.7219280948873623), 'class': 0},
#    5: {'label': 'End', 'entropy': 0, 'class': 0},
#    8: {'label': 'End', 'entropy': 0, 'class': 0}}},
#  {'label': 'Parch',
#   'entropy': np.float64(0.9358573442730366),
#   'next': {0: {'label': 'Sex',
#     'entropy': np.float64(0.9182958340544896),
#     'next': {0: {'label': 'Pclass',
#       'entropy': np.float64(0.7108984414464207),
#       'next': {1: {'label': 'Fare',
#         'entropy': np.float64(0.9828586897127056),
#         'next': {0.0: {'label': 'Age',
#           'entropy': np.float64(0.9828586897127056),
#           'next': {2.0: {'label': 'Embarked',
#             'entropy': np.float64(0.863120568566631),
#             'next': {0.0: {'label': 'End',
#               'entropy': np.float64(0.6500224216483541),
#               'class': 0},
#              1.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#            3.0: {'label': 'End',
#             'entropy': np.float64(0.7219280948873623),
#             'class': 1},
#            4.0: {'label': 'End',
#             'entropy': np.float64(0.954434002924965),
#             'class': 0},
#            5.0: {'label': 'End', 'entropy': 0, 'class': 1},
#            6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#            7.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          1.0: {'label': 'SibSp',
#           'entropy': np.float64(0.9980008838722995),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.8112781244591328),
#             'class': 0},
#            1: {'label': 'End',
#             'entropy': np.float64(0.9967916319816366),
#             'class': 1}}},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          4.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          10.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#        2: {'label': 'End',
#         'entropy': np.float64(0.5185697317883058),
#         'class': 0},
#        3: {'label': 'End',
#         'entropy': np.float64(0.5893886812927801),
#         'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.8481636883083002),
#       'class': 1}}},
#    1: {'label': 'End', 'entropy': np.float64(0.9990102708804813), 'class': 1},
#    2: {'label': 'End', 'entropy': np.float64(0.9275265884316759), 'class': 0},
#    3: {'label': 'End', 'entropy': 0, 'class': 1},
#    4: {'label': 'End', 'entropy': 0, 'class': 0},
#    5: {'label': 'End', 'entropy': 0, 'class': 0},
#    6: {'label': 'End', 'entropy': 0, 'class': 0}}},
#  {'label': 'SibSp',
#   'entropy': np.float64(0.9690847476951423),
#   'next': {0: {'label': 'Sex',
#     'entropy': np.float64(0.934068055375491),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.6868088934028035),
#       'next': {0.0: {'label': 'End', 'entropy': 0, 'class': 1},
#        1.0: {'label': 'Pclass',
#         'entropy': np.float64(0.7871265862012691),
#         'next': {2: {'label': 'Fare',
#           'entropy': np.float64(0.5916727785823273),
#           'next': {0.0: {'label': 'End',
#             'entropy': np.float64(0.6500224216483541),
#             'class': 0},
#            1.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          3: {'label': 'End',
#           'entropy': np.float64(0.8812908992306927),
#           'class': 0}}},
#        2.0: {'label': 'Embarked',
#         'entropy': np.float64(0.584238811642856),
#         'next': {0.0: {'label': 'Parch',
#           'entropy': np.float64(0.6115516951951331),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.616748259826391),
#             'class': 0},
#            1: {'label': 'End', 'entropy': 0, 'class': 0}}},
#          1.0: {'label': 'End',
#           'entropy': np.float64(0.6500224216483541),
#           'class': 0},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.693127415328288),
#         'class': 0},
#        4.0: {'label': 'End',
#         'entropy': np.float64(0.6098403047164004),
#         'class': 0},
#        5.0: {'label': 'End',
#         'entropy': np.float64(0.5916727785823273),
#         'class': 0},
#        6.0: {'label': 'End',
#         'entropy': np.float64(0.863120568566631),
#         'class': 0},
#        8.0: {'label': 'End', 'entropy': 0, 'class': 1}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.7973265101474423),
#       'class': 1}}},
#    1: {'label': 'End', 'entropy': np.float64(0.9862958176866949), 'class': 1},
#    2: {'label': 'End', 'entropy': np.float64(0.9709505944546686), 'class': 1},
#    3: {'label': 'End', 'entropy': np.float64(0.6500224216483541), 'class': 0},
#    4: {'label': 'End', 'entropy': 0, 'class': 0},
#    5: {'label': 'End', 'entropy': 0, 'class': 0},
#    8: {'label': 'End', 'entropy': 0, 'class': 0}}},
#  {'label': 'Pclass',
#   'entropy': np.float64(0.9378152393208243),
#   'next': {1: {'label': 'Sex',
#     'entropy': np.float64(0.9789987370022761),
#     'next': {0: {'label': 'Age',
#       'entropy': np.float64(0.9690632527820693),
#       'next': {1.0: {'label': 'Parch',
#         'entropy': np.float64(1.0),
#         'next': {0: {'label': 'End', 'entropy': 0, 'class': 0},
#          2: {'label': 'End', 'entropy': 0, 'class': 1}}},
#        2.0: {'label': 'Fare',
#         'entropy': np.float64(0.954434002924965),
#         'next': {0.0: {'label': 'Embarked',
#           'entropy': np.float64(0.9402859586706311),
#           'next': {0.0: {'label': 'End',
#             'entropy': np.float64(0.9182958340544896),
#             'class': 0},
#            1.0: {'label': 'End',
#             'entropy': np.float64(0.9709505944546686),
#             'class': 0}}},
#          1.0: {'label': 'SibSp',
#           'entropy': np.float64(1.0),
#           'next': {0: {'label': 'End',
#             'entropy': np.float64(0.9182958340544896),
#             'class': 0},
#            1: {'label': 'End',
#             'entropy': np.float64(0.9709505944546686),
#             'class': 1}}},
#          2.0: {'label': 'End', 'entropy': 0, 'class': 0},
#          4.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#        3.0: {'label': 'End',
#         'entropy': np.float64(0.9940302114769565),
#         'class': 1},
#        4.0: {'label': 'End', 'entropy': np.float64(1.0), 'class': 1},
#        5.0: {'label': 'End',
#         'entropy': np.float64(0.9709505944546686),
#         'class': 0},
#        6.0: {'label': 'End', 'entropy': 0, 'class': 0},
#        7.0: {'label': 'End', 'entropy': 0, 'class': 0}}},
#      1: {'label': 'End',
#       'entropy': np.float64(0.20559250818508293),
#       'class': 1}}},
#    2: {'label': 'End', 'entropy': np.float64(0.990374836448575), 'class': 0},
#    3: {'label': 'End',
#     'entropy': np.float64(0.7777300323134144),
#     'class': 0}}}]

# %% [markdown]
# # Testing

# %%
def testForest(data,models):
  correct = 0
  for i in data.index:
    vote = 0
    for model in models:
      layer = model
      while not layer['label'] == 'End':
        value = data[layer['label']][i]
        if value in layer['next']:
          layer = layer['next'][value]
        else:
          keys = list(layer['next'].keys())
          before = keys[0]
          for k in keys:
            after = k
            if(after > value): break
            before = k
          if after - value < value - before:
            layer = layer['next'][after]
          else:
            layer = layer['next'][before]
      vote += layer['class']
    vote = (0 if vote < 5 else 1)
    if vote == data['Survived'][i]: correct += 1
  return correct / len(data)

# %%
testForest(data,models)
# Out:
# 0.7901234567901234

# %% [markdown]
# # Evaluation

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,11):
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,len(labels),10,i*.1)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.7640449438202247
# 2: 0.7415730337078652
# 3: 0.7640449438202247
# 4: 0.7752808988764045
# 5: 0.7528089887640449
# 6: 0.7696629213483146
# 7: 0.7696629213483146
# 8: 0.7921348314606742
# 9: 0.7640449438202247
# 10: 0.7696629213483146

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,30):
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,len(labels),i,.8)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.6573033707865169
# 2: 0.6573033707865169
# 3: 0.6573033707865169
# 4: 0.6573033707865169
# 5: 0.7584269662921348
# 6: 0.7471910112359551
# 7: 0.7808988764044944
# 8: 0.7471910112359551
# 9: 0.7921348314606742
# 10: 0.7808988764044944
# 11: 0.7808988764044944
# 12: 0.7528089887640449
# 13: 0.7696629213483146
# 14: 0.7247191011235955
# 15: 0.7808988764044944
# 16: 0.6966292134831461
# 17: 0.7303370786516854
# 18: 0.6966292134831461
# 19: 0.7303370786516854
# 20: 0.7528089887640449
# 21: 0.6460674157303371
# 22: 0.7247191011235955
# 23: 0.6910112359550562
# 24: 0.6966292134831461
# 25: 0.6797752808988764
# 26: 0.6966292134831461
# 27: 0.6460674157303371
# 28: 0.6629213483146067
# 29: 0.6741573033707865

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,11):
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,len(labels),10,i*.1,random=False)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.7696629213483146
# 2: 0.8033707865168539
# 3: 0.8033707865168539
# 4: 0.8033707865168539
# 5: 0.797752808988764
# 6: 0.8033707865168539
# 7: 0.8033707865168539
# 8: 0.8033707865168539
# 9: 0.8033707865168539
# 10: 0.8033707865168539

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
for i in range(1,30):
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,len(labels),i,.8,random=False)
  print(str(i) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.5955056179775281
# 2: 0.5955056179775281
# 3: 0.5955056179775281
# 4: 0.5955056179775281
# 5: 0.8370786516853933
# 6: 0.8426966292134831
# 7: 0.8314606741573034
# 8: 0.8426966292134831
# 9: 0.848314606741573
# 10: 0.8595505617977528
# 11: 0.848314606741573
# 12: 0.8595505617977528
# 13: 0.8314606741573034
# 14: 0.8370786516853933
# 15: 0.8314606741573034
# 16: 0.8539325842696629
# 17: 0.797752808988764
# 18: 0.8146067415730337
# 19: 0.8258426966292135
# 20: 0.8314606741573034
# 21: 0.8314606741573034
# 22: 0.7921348314606742
# 23: 0.8258426966292135
# 24: 0.7921348314606742
# 25: 0.7921348314606742
# 26: 0.8033707865168539
# 27: 0.8314606741573034
# 28: 0.7921348314606742
# 29: 0.7808988764044944

# %%
data = transform(raw_train)
data['Survived'] = raw_train['Survived']
training = data.sample(frac=.8)
validation = data.drop(training.index)
labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
for i in range(len(labels)):
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,i+1,10,.8,random=False)
  print(str(i+1) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.8146067415730337
# 2: 0.7808988764044944
# 3: 0.8146067415730337
# 4: 0.8258426966292135
# 5: 0.8146067415730337
# 6: 0.8258426966292135
# 7: 0.8258426966292135
# 8: 0.8202247191011236

# %%
for a in range(1,100,1):
  data = transform(raw_train,age_bin=a)
  data['Survived'] = raw_train['Survived']
  training = data.sample(frac=.8)
  validation = data.drop(training.index)
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,len(labels),10,.8,random=False)
  print(str(a) + ': ' + str(testForest(validation,models)))
# Out:
# 1: 0.7359550561797753
# 2: 0.848314606741573
# 3: 0.8595505617977528
# 4: 0.7752808988764045
# 5: 0.8146067415730337
# 6: 0.8314606741573034
# 7: 0.7865168539325843
# 8: 0.8202247191011236
# 9: 0.8258426966292135
# 10: 0.8595505617977528
# 11: 0.7921348314606742
# 12: 0.8370786516853933
# 13: 0.7865168539325843
# 14: 0.7359550561797753
# 15: 0.7415730337078652
# 16: 0.7752808988764045
# 17: 0.7808988764044944
# 18: 0.8370786516853933
# 19: 0.7584269662921348
# 20: 0.7640449438202247
# 21: 0.7640449438202247
# 22: 0.7584269662921348
# 23: 0.8033707865168539
# 24: 0.7415730337078652
# 25: 0.7528089887640449
# 26: 0.7865168539325843
# 27: 0.7640449438202247
# 28: 0.7865168539325843
# 29: 0.7865168539325843
# 30: 0.8202247191011236
# 31: 0.7471910112359551
# 32: 0.8089887640449438
# 33: 0.7808988764044944
# 34: 0.7808988764044944
# 35: 0.7696629213483146
# 36: 0.7696629213483146
# 37: 0.7359550561797753
# 38: 0.7921348314606742
# 39: 0.7696629213483146
# 40: 0.7303370786516854
# 41: 0.7921348314606742
# 42: 0.7752808988764045
# 43: 0.7584269662921348
# 44: 0.848314606741573
# 45: 0.797752808988764
# 46: 0.8202247191011236
# 47: 0.7584269662921348
# 48: 0.7528089887640449
# 49: 0.7865168539325843
# 50: 0.7696629213483146
# 51: 0.7865168539325843
# 52: 0.7752808988764045
# 53: 0.7865168539325843
# 54: 0.7415730337078652
# 55: 0.7865168539325843
# 56: 0.7584269662921348
# 57: 0.7640449438202247
# 58: 0.7584269662921348
# 59: 0.797752808988764
# 60: 0.7752808988764045
# 61: 0.7640449438202247
# 62: 0.8089887640449438
# 63: 0.8033707865168539
# 64: 0.7808988764044944
# 65: 0.8146067415730337
# 66: 0.7752808988764045
# 67: 0.7584269662921348
# 68: 0.7865168539325843
# 69: 0.8202247191011236
# 70: 0.7752808988764045
# 71: 0.7752808988764045
# 72: 0.8089887640449438
# 73: 0.8033707865168539
# 74: 0.7752808988764045
# 75: 0.8202247191011236
# 76: 0.7696629213483146
# 77: 0.8314606741573034
# 78: 0.7808988764044944
# 79: 0.7752808988764045
# 80: 0.7640449438202247
# 81: 0.7808988764044944
# 82: 0.7808988764044944
# 83: 0.7921348314606742
# 84: 0.7584269662921348
# 85: 0.7808988764044944
# 86: 0.797752808988764
# 87: 0.8089887640449438
# 88: 0.7808988764044944
# 89: 0.7808988764044944
# 90: 0.7415730337078652
# 91: 0.7640449438202247
# 92: 0.7640449438202247
# 93: 0.7921348314606742
# 94: 0.7247191011235955
# 95: 0.7471910112359551
# 96: 0.7415730337078652
# 97: 0.7696629213483146
# 98: 0.7640449438202247
# 99: 0.7359550561797753

# %%
for f in range(5,500,5):
  data = transform(raw_train,age_bin=10,fare_bin=f)
  data['Survived'] = raw_train['Survived']
  training = data.sample(frac=.8)
  validation = data.drop(training.index)
  labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
  models = trainForest(training,len(labels),10,.8,random=False)
  print(str(f) + ': ' + str(testForest(validation,models)))
# Out:
# 5: 0.7865168539325843
# 10: 0.8202247191011236
# 15: 0.7808988764044944
# 20: 0.7921348314606742
# 25: 0.8146067415730337
# 30: 0.7640449438202247
# 35: 0.7584269662921348
# 40: 0.7808988764044944
# 45: 0.8146067415730337
# 50: 0.7808988764044944
# 55: 0.797752808988764
# 60: 0.8370786516853933
# 65: 0.7921348314606742
# 70: 0.7752808988764045
# 75: 0.797752808988764
# 80: 0.8033707865168539
# 85: 0.7640449438202247
# 90: 0.8258426966292135
# 95: 0.8202247191011236
# 100: 0.8089887640449438
# 105: 0.7528089887640449
# 110: 0.7640449438202247
# 115: 0.8033707865168539
# 120: 0.7640449438202247
# 125: 0.7865168539325843
# 130: 0.8089887640449438
# 135: 0.8146067415730337
# 140: 0.8370786516853933
# 145: 0.797752808988764
# 150: 0.7752808988764045
# 155: 0.7303370786516854
# 160: 0.7752808988764045
# 165: 0.7584269662921348
# 170: 0.7696629213483146
# 175: 0.7921348314606742
# 180: 0.7808988764044944
# 185: 0.7921348314606742
# 190: 0.797752808988764
# 195: 0.7752808988764045
# 200: 0.797752808988764
# 205: 0.8258426966292135
# 210: 0.7921348314606742
# 215: 0.7696629213483146
# 220: 0.7528089887640449
# 225: 0.797752808988764
# 230: 0.797752808988764
# 235: 0.8202247191011236
# 240: 0.7808988764044944
# 245: 0.8202247191011236
# 250: 0.8426966292134831
# 255: 0.8089887640449438
# 260: 0.8258426966292135
# 265: 0.7808988764044944
# 270: 0.7752808988764045
# 275: 0.7584269662921348
# 280: 0.8033707865168539
# 285: 0.8089887640449438
# 290: 0.8146067415730337
# 295: 0.8089887640449438
# 300: 0.7640449438202247
# 305: 0.8258426966292135
# 310: 0.7921348314606742
# 315: 0.7752808988764045
# 320: 0.8595505617977528
# 325: 0.7471910112359551
# 330: 0.7640449438202247
# 335: 0.7640449438202247
# 340: 0.8202247191011236
# 345: 0.8089887640449438
# 350: 0.7696629213483146
# 355: 0.7303370786516854
# 360: 0.7696629213483146
# 365: 0.8258426966292135
# 370: 0.7640449438202247
# 375: 0.8314606741573034
# 380: 0.8651685393258427
# 385: 0.7528089887640449
# 390: 0.8033707865168539
# 395: 0.7696629213483146
# 400: 0.8033707865168539
# 405: 0.8146067415730337
# 410: 0.8202247191011236
# 415: 0.8202247191011236
# 420: 0.7921348314606742
# 425: 0.848314606741573
# 430: 0.7247191011235955
# 435: 0.8314606741573034
# 440: 0.8146067415730337
# 445: 0.8089887640449438
# 450: 0.8089887640449438
# 455: 0.8146067415730337
# 460: 0.702247191011236
# 465: 0.8370786516853933
# 470: 0.8202247191011236
# 475: 0.8314606741573034
# 480: 0.8258426966292135
# 485: 0.8202247191011236
# 490: 0.8202247191011236
# 495: 0.8089887640449438

# %% [markdown]
# # Prediction

# %%
def predictForest(data,models):
  out = pd.DataFrame(columns=['PassengerId','Survived'])
  out['PassengerId'] = data['PassengerId']
  for i in data.index:
    vote = 0
    for model in models:
      layer = model
      while not layer['label'] == 'End':
        value = data[layer['label']][i]
        if value in layer['next']:
          layer = layer['next'][value]
        else:
          keys = list(layer['next'].keys())
          before = keys[0]
          for k in keys:
            after = k
            if(after > value): break
            before = k
          if after - value < value - before:
            layer = layer['next'][after]
          else:
            layer = layer['next'][before]
      vote += layer['class']
    vote = 0 if vote < 5 else 1
    out.loc[i,'Survived'] = vote
  return out

# %%
data = transform(raw_train,age_bin=10,fare_bin=100)
data['Survived'] = raw_train['Survived']
labels = ['Pclass','Title','Sex','Age','SibSp','Parch','Fare','Embarked']
models = trainForest(data,len(labels),10,.8,random=False)

# %%
data = transform(raw_test,age_bin=5,fare_bin=20)
data['PassengerId'] = raw_test['PassengerId']
out = predictForest(data,models)
out.to_csv('RandomForest.csv', index = False)
out
# Out:
#      PassengerId Survived
# 0            892        0
# 1            893        1
# 2            894        0
# 3            895        0
# 4            896        1
# ..           ...      ...
# 413         1305        0
# 414         1306        1
# 415         1307        0
# 416         1308        0
# 417         1309        0
#
# [418 rows x 2 columns]
